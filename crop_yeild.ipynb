# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import plotly
import seaborn as sns
import joblib

# %%
data=pd.read_csv(r'Crop Yiled with Soil and Weather.csv')
data
# Out:
#       Fertilizer       temp          N          P          K      yeild
# 0      80.000000  28.000000  80.000000  24.000000  20.000000  12.000000
# 1      77.000000  27.000000  78.000000  23.000000  20.000000  12.000000
# 2      80.000000  26.000000  80.000000  24.000000  20.000000  12.000000
# 3      80.000000  28.000000  80.000000  24.000000  20.000000  12.000000
# 4      78.000000  27.000000  78.000000  23.000000  19.000000  12.000000
# ...          ...        ...        ...        ...        ...        ...
# 2591   78.942684  27.014634  76.838312  23.087606  20.044206  10.348503
# 2592   79.077362  27.153127  76.927657  23.068234  20.155436  10.528122
# 2593   78.986271  28.108948  77.164352  22.863654  20.989871  10.564205
# 2594   78.894767  28.141344  76.925149  23.071553  20.873662  10.442511
# 2595   79.050307  26.980865  77.124758  23.050197  19.960695  10.584638
#
# [2596 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2596 entries, 0 to 2595
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fertilizer  2596 non-null   float64
#  1   temp        2596 non-null   float64
#  2   N           2596 non-null   float64
#  3   P           2596 non-null   float64
#  4   K           2596 non-null   float64
#  5   yeild       2596 non-null   float64
# dtypes: float64(6)
# memory usage: 121.8 KB

# %%
data.describe()
# Out:
#         Fertilizer         temp            N            P            K  \
# count  2596.000000  2596.000000  2596.000000  2596.000000  2596.000000
# mean     66.487433    33.848237    69.522900    20.708194    17.806268
# std       9.747669     5.371279     6.802806     1.973419     1.940037
# min      49.751436    23.771310    58.839466    17.723223    14.704883
# 25%      59.865423    28.000000    64.834635    18.988224    15.975932
# 50%      65.011969    36.965121    69.894076    20.889579    18.061975
# 75%      76.943112    38.928914    76.845919    22.125618    19.133858
# max      80.223893    40.272480    80.218705    25.162178    22.064666
#
#              yeild
# count  2596.000000
# mean      8.533832
# std       1.938789
# min       5.150745
# 25%       6.929404
# 50%       8.501720
# 75%      10.045179
# max      12.337651

# %%
data.isnull().sum()
# Out:
# Fertilizer    0
# temp          0
# N             0
# P             0
# K             0
# yeild         0
# dtype: int64

# %%
corr_data=data.corr()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_data,annot=True,cmap='coolwarm')
plt.title('Correlataion')
# Out:
# Text(0.5, 1.0, 'Correlataion')

# %%
plt.figure(figsize=(8,5))
plt.scatter(data['Fertilizer'],data['yeild'])
plt.title('Fertilizer Vs Yeild')
plt.xlabel('Fertilizer')
plt.ylabel('Yeild')
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# C:\Users\Master\AppData\Local\Temp\ipykernel_2064\3587523666.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(8,5))
plt.hexbin(data['temp'],data['yeild'], gridsize=20, cmap='Blues')  # hexbin
plt.title('Effect of temprature on Yield')
plt.xlabel('Temprature')
plt.ylabel('Yield')
plt.colorbar(label='Count')  # shows density of points
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x=data['N'],y=data['yeild'])
plt.title('Effect of nitrogrn on yeild')
plt.xlabel('Nitrogen')
plt.ylabel('yeild')
plt.legend()
plt.show()
# Out:
# C:\Users\Master\AppData\Local\Temp\ipykernel_2064\822442236.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.pairplot(data, y_vars=['yeild'], x_vars=["Fertilizer","temp","N","P","K"])
plt.show()

# %%
features = ["Fertilizer", "temp", "N", "P", "K"]

for col in features:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=data[col], y=data['yeild'])
    plt.title(f"{col} vs Yield")
    plt.xlabel(col)
    plt.ylabel("Yield")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
Rf=RandomForestRegressor(n_estimators=100,random_state=42)

# %%
X=data.drop('yeild',axis=1)
y=data['yeild']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.1,random_state=42)

# %%
model=Rf.fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 0.03228155886621229
# Mean Absolute Error: 0.1186908403370358
# R2 Score: 0.9910733413884052

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, color="blue", edgecolor="k")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # ideal line
plt.xlabel("Actual Yield")
plt.ylabel("Predicted Yield")
plt.title("Random Forest: Actual vs Predicted Yield")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
importances = model.feature_importances_
features = X.columns

plt.figure(figsize=(7,5))
plt.barh(features, importances, color="green")
plt.xlabel("Importance")
plt.title("Feature Importance in Random Forest")
plt.show()

# %%
residuals = y_test - y_pred

plt.figure(figsize=(7,5))
plt.scatter(y_pred, residuals, color="purple", edgecolor="k")
plt.axhline(0, color='r', linestyle='--')
plt.xlabel("Predicted Yield")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
print(residuals)
# Out:
# 211     0.060970
# 2122    0.039757
# 1739    0.041601
# 2421   -0.323696
# 1670   -0.152691
#           ...
# 443     0.035839
# 450    -0.010064
# 2059   -0.072248
# 2495    0.037708
# 2287    0.019408
# Name: yeild, Length: 260, dtype: float64

# %%
# New data (Fertilizer, temp, N, P, K)
new_data = np.array([[79.050307, 26.980865, 77.124758, 23.050197, 19.960695]])

# %%
new_pred=model.predict(new_data)
# Out:
# C:\Users\Master\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
new_pred
# Out:
# array([10.5475232])

# %%
joblib.dump(model, "crop_model.pkl")
# Out:
# ['crop_model.pkl']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

scores = cross_val_score(
    rf,
    X,
    y,
    cv=5,
    scoring='r2'
)

print("Cross Validation Scores:", scores)
print("Average CV Score:", scores.mean())
# Out:
# Cross Validation Scores: [ 0.64444563 -0.65855435  0.65792331 -0.01014624  0.20014314]
# Average CV Score: 0.16676229998224928
